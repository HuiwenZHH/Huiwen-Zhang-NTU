# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Let e(t),s(t),p(t),es(t), be the concentration of the enzyme E, the substrate S,the product P, and the complex with S at time t,then
# the equations for the rate of changes of the four species, E, S, ES, and P are:
# de/dt  = -k1*e*s+(K2+K3)*es
# ds/dt =-k1*e*s+600*es
# des/dt=k1*e*s-(k2+k3)*es
# dp/dt=k3*es

# %%
def euler(x,f,h):
    m1=h*f(x)
    m2=h*f(x+0.5*m1)
    m3=h*f(x+0.5*m2)
    m4=h*f(x+m3)
    return x+(1/6)*(m1+2*m2+2*m3+m4)


def dX_dt(var):
    e,s,es,p=var[0],var[1],var[2],var[3]
    return np.array([-k1*e*s+(k2+k3)*es,-k1*e*s+k2*es,k1*e*s-(k2+k3)*es,k3*es])

# %%
k1,k2,k3=100/60,600/60,150/60
var=[1,10,0,0]
t=0
h=0.01
E_VAL=[]
S_VAL=[]
ES_VAL=[]
P_VAL=[]
T_VAL=[]
steady_e=[]
steady_s=[]
steady_es=[]
steady_p=[]
    
V=[]

while t<40:
    var=euler(var,dX_dt,h)
    E_VAL.append(var[0])
    S_VAL.append(var[1])
    ES_VAL.append(var[2])
    P_VAL.append(var[3])
    V.append(k3*var[2])
    t+=h
    T_VAL.append(t)
    
    # From the graph, we can see that the system approches steady state after t=25, so we get the solution by averaging over the values during t=25 to t=40:
    if t>25:
        steady_e.append(var[0])
        steady_s.append(var[1])
        steady_es.append(var[2])
        steady_p.append(var[3])
print("The value of enzyme",sum(steady_e)/len(steady_e))
print("The value of substrate",sum(steady_s)/len(steady_s))
print("The value of complex",sum(steady_es)/len(steady_es))
print("The value of product",sum(steady_p)/len(steady_p))

plt.plot(T_VAL,E_VAL,label="enzyme")
plt.plot(T_VAL,S_VAL,label="substrate")
plt.plot(T_VAL,ES_VAL,label="complex")
plt.plot(T_VAL,P_VAL,label="product")
plt.xlabel("time(s)")
plt.ylabel("concentration($\mu$ M)")
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.7),fontsize=12)
# Out:
# The value of enzyme 0.9995482928607007
# The value of substrate 0.003309962550522968
# The value of complex 0.000451707139302187
# The value of product 9.996238330310149

# %%
plt.plot(V,S_VAL)
plt.xlabel("V=dP/dt")
plt.ylabel("concentration of S")
# plt.xticks(list(np.arange(0,1.5,0.1)))
# plt.yticks(list(np.arange(6,10,0.5)))
# Out:
# Text(0, 0.5, 'concentration of S')

# %% [markdown]
# From the plot, it can be seen that the Vm is approximately equal to 1.4 $\mu$ M/s , when S=9$\mu$M and when S>9 $\mu$M, V will be less that 1.4 $\mu$M/s
